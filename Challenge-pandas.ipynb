# %% [markdown]
# ## Ejercicio 1.1

# %% [markdown]
# ### Contar el numero de lineas para cada archivo

# %%
bookings = '/Users/giuliagalli/Documents/Master Data Science/Clases Master/challenge/bookings.csv'
searches = '/Users/giuliagalli/Documents/Master Data Science/Clases Master/challenge/searches.csv'

import bz2
import pandas as pd

# %%
bz2.decompress?

# %%
bz2_bookings = bz2.BZ2File(bookings)

import pandas as pd

# %%
data = bz2.decompress(bz2.BZ2File(bookings).read())
# Out:
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# <ipython-input-34-746c153730d5> in <module>
# ----> 1 data = bz2.decompress(bz2.BZ2File(bookings).read())
#
# /Applications/anaconda3/lib/python3.6/bz2.py in decompress(data)
#     348         decomp = BZ2Decompressor()
#     349         try:
# --> 350             res = decomp.decompress(data)
#     351         except OSError:
#     352             if results:
#
# OSError: Invalid data stream

# %% [markdown]
# data = bz2.decompress(bz2.BZ2File(bookings).read())

# %%
df_booking = pd.read_csv(bookings, error_bad_lines=False, sep='^')
# Out:
# /Applications/anaconda3/lib/python3.6/site-packages/IPython/core/interactiveshell.py:3020: DtypeWarning: Columns (7,8,27) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %%
df_searches = pd.read_csv(searches, error_bad_lines=False, sep='^')
# Out:
# /Applications/anaconda3/lib/python3.6/site-packages/IPython/core/interactiveshell.py:3020: DtypeWarning: Columns (40,41,42,44) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %%
len(df_booking.index)
# Out:
# 10000010

# %%
len(df_searches.index)
# Out:
# 20390198

# %% [markdown]
# ## Ejercicio 2.1

# %%
df_booking.columns
# Out:
# Index(['act_date           ', 'source', 'pos_ctry', 'pos_iata', 'pos_oid  ',
#        'rloc          ', 'cre_date           ', 'duration', 'distance',
#        'dep_port', 'dep_city', 'dep_ctry', 'arr_port', 'arr_city', 'arr_ctry',
#        'lst_port', 'lst_city', 'lst_ctry', 'brd_port', 'brd_city', 'brd_ctry',
#        'off_port', 'off_city', 'off_ctry', 'mkt_port', 'mkt_city', 'mkt_ctry',
#        'intl', 'route          ', 'carrier', 'bkg_class', 'cab_class',
#        'brd_time           ', 'off_time           ', 'pax', 'year', 'month',
#        'oid      '],
#       dtype='object')

# %%
df_booking
# Out:
#           act_date             source  pos_ctry  \
# 0         2013-03-05 00:00:00  1A      DE
# 1         2013-03-26 00:00:00  1A      US
# 2         2013-03-26 00:00:00  1A      US
# 3         2013-03-26 00:00:00  1A      AU
# 4         2013-03-26 00:00:00  1A      AU
# 5         2013-03-20 00:00:00  1V      US
# 6         2013-03-20 00:00:00  1V      US
# 7         2013-03-25 00:00:00  1V      JP
# 8         2013-03-25 00:00:00  1V      JP
# 9         2013-03-25 00:00:00  1V      JP
# 10        2013-03-25 00:00:00  1V      JP
# 11        2013-03-28 00:00:00  1V      JP
# 12        2013-03-28 00:00:00  1V      JP
# 13        2013-03-28 00:00:00  1V      JP
# 14        2013-03-28 00:00:00  1V      JP
# 15        2013-03-28 00:00:00  1V      JP
# 16        2013-03-28 00:00:00  1V      JP
# 17        2013-03-28 00:00:00  1V      JP
# 18        2013-03-28 00:00:00  1V      JP
# 19        2013-03-13 00:00:00  1V      CA
# 20        2013-03-25 00:00:00  1A      IT
# ...

# %%
df_searches.columns
# Out:
# Index(['Date', 'Time', 'TxnCode', 'OfficeID', 'Country', 'Origin',
#        'Destination', 'RoundTrip', 'NbSegments', 'Seg1Departure',
#        'Seg1Arrival', 'Seg1Date', 'Seg1Carrier', 'Seg1BookingCode',
#        'Seg2Departure', 'Seg2Arrival', 'Seg2Date', 'Seg2Carrier',
#        'Seg2BookingCode', 'Seg3Departure', 'Seg3Arrival', 'Seg3Date',
#        'Seg3Carrier', 'Seg3BookingCode', 'Seg4Departure', 'Seg4Arrival',
#        'Seg4Date', 'Seg4Carrier', 'Seg4BookingCode', 'Seg5Departure',
#        'Seg5Arrival', 'Seg5Date', 'Seg5Carrier', 'Seg5BookingCode',
#        'Seg6Departure', 'Seg6Arrival', 'Seg6Date', 'Seg6Carrier',
#        'Seg6BookingCode', 'From', 'IsPublishedForNeg', 'IsFromInternet',
#        'IsFromVista', 'TerminalID', 'InternetOffice'],
#       dtype='object')

# %%
top10 = df_booking.groupby('arr_port') ['pax'].sum()
top10
# Out:
# arr_port
# AAB            30.0
# AAE           810.0
# AAL           810.0
# AAN            20.0
# AAQ          1650.0
# AAR           500.0
# ABA            90.0
# ABB            40.0
# ABE           880.0
# ABI           150.0
# ABJ          2600.0
# ABK             0.0
# ABQ          4290.0
# ABR             0.0
# ABS           310.0
# ABT           300.0
# ABV          1950.0
# ABX           300.0
# ABY            90.0
# ABZ          3710.0
# ACA           700.0
# ACC          3810.0
# ACE          1700.0
# ACH            20.0
# ACI            40.0
# ACK           200.0
# ACT           180.0
# ACV           140.0
# ACY           190.0
# ADA           980.0
#              ...
# ZAZ            50.0
# ZBF           110.0
# ZBL            90.0
# ZCL           150.0
# ZCO           490.0
# ZDH            60.0
# ZFQ            40.0
# ZFV           120.0
# ZHA             0.0
# ZIG            40.0
# ZIH           870.0
# ZLN             0.0
# ZLO           500.0
# ZNE          1510.0
# ...

# %%
top10.reset_index().sort_values('pax', ascending = False).head(10)
# Out:
#       arr_port      pax
# 1088  LHR       88809.0
# 1190  MCO       70930.0
# 1050  LAX       70530.0
# 1047  LAS       69630.0
# 886   JFK       66270.0
# 315   CDG       64490.0
# 216   BKK       59460.0
# 1228  MIA       58150.0
# 1719  SFO       58000.0
# 517   DXB       55590.0

# %% [markdown]
# ## Ejercicio 2.3

# %%
import matplotlib.pyplot as plt
import matplotlib

# %%
df_searches.columns
# Out:
# Index(['Date', 'Time', 'TxnCode', 'OfficeID', 'Country', 'Origin',
#        'Destination', 'RoundTrip', 'NbSegments', 'Seg1Departure',
#        'Seg1Arrival', 'Seg1Date', 'Seg1Carrier', 'Seg1BookingCode',
#        'Seg2Departure', 'Seg2Arrival', 'Seg2Date', 'Seg2Carrier',
#        'Seg2BookingCode', 'Seg3Departure', 'Seg3Arrival', 'Seg3Date',
#        'Seg3Carrier', 'Seg3BookingCode', 'Seg4Departure', 'Seg4Arrival',
#        'Seg4Date', 'Seg4Carrier', 'Seg4BookingCode', 'Seg5Departure',
#        'Seg5Arrival', 'Seg5Date', 'Seg5Carrier', 'Seg5BookingCode',
#        'Seg6Departure', 'Seg6Arrival', 'Seg6Date', 'Seg6Carrier',
#        'Seg6BookingCode', 'From', 'IsPublishedForNeg', 'IsFromInternet',
#        'IsFromVista', 'TerminalID', 'InternetOffice'],
#       dtype='object')

# %%
df_searches.head(5)
# Out:
#          Date      Time TxnCode                          OfficeID Country  \
# 0  2013-01-01  20:25:57     MPT  624d8c3ac0b3a7ca03e3c167e0f48327      DE
# 1  2013-01-01  10:15:33     MPT  b0af35b31588dc4ab06d5cf2986e8e02      MD
# 2  2013-01-01  18:04:49     MPT  3561a60621de06ab1badc8ca55699ef3      US
# 3  2013-01-01  17:42:40     FXP  1864e5e8013d9414150e91d26b6a558b      SE
# 4  2013-01-01  17:48:29     MPT  1ec336348f44207d2e0027dc3a68c118      NO
#
#   Origin Destination  RoundTrip  NbSegments Seg1Departure      ...        \
# 0    TXL         AUH        1.0         2.0           TXL      ...
# 1    ATH         MIL        0.0         1.0           ATH      ...
# 2    ICT         SFO        1.0         2.0           ICT      ...
# 3    RNB         ARN        0.0         1.0           RNB      ...
# 4    OSL         MAD        1.0         2.0           OSL      ...
#
#   Seg6Arrival Seg6Date Seg6Carrier Seg6BookingCode    From IsPublishedForNeg  \
# ...

# %%
df_searches.dtypes
# Out:
# Date                  object
# Time                  object
# TxnCode               object
# OfficeID              object
# Country               object
# Origin                object
# Destination           object
# RoundTrip            float64
# NbSegments           float64
# Seg1Departure         object
# Seg1Arrival           object
# Seg1Date              object
# Seg1Carrier           object
# Seg1BookingCode       object
# Seg2Departure         object
# Seg2Arrival           object
# Seg2Date              object
# Seg2Carrier           object
# Seg2BookingCode       object
# Seg3Departure         object
# Seg3Arrival           object
# Seg3Date              object
# Seg3Carrier           object
# Seg3BookingCode       object
# Seg4Departure         object
# Seg4Arrival           object
# Seg4Date              object
# Seg4Carrier           object
# Seg4BookingCode       object
# Seg5Departure         object
# Seg5Arrival           object
# Seg5Date              object
# ...

# %%
date_time = pd.to_datetime(df_searches['Date'] + ' ' + df_searches['Time'])
df_searches['DateTime'] = date_time

# %%
df_searches.dtypes
# Out:
# Date                         object
# Time                         object
# TxnCode                      object
# OfficeID                     object
# Country                      object
# Origin                       object
# Destination                  object
# RoundTrip                   float64
# NbSegments                  float64
# Seg1Departure                object
# Seg1Arrival                  object
# Seg1Date                     object
# Seg1Carrier                  object
# Seg1BookingCode              object
# Seg2Departure                object
# Seg2Arrival                  object
# Seg2Date                     object
# Seg2Carrier                  object
# Seg2BookingCode              object
# Seg3Departure                object
# Seg3Arrival                  object
# Seg3Date                     object
# Seg3Carrier                  object
# Seg3BookingCode              object
# Seg4Departure                object
# Seg4Arrival                  object
# ...

# %%
import datetime

# %%
df_searches['Month'] = pd.DatetimeIndex(df_searches['DateTime']).month
df_searches.head(5)
# Out:
#          Date      Time TxnCode                          OfficeID Country  \
# 0  2013-01-01  20:25:57     MPT  624d8c3ac0b3a7ca03e3c167e0f48327      DE
# 1  2013-01-01  10:15:33     MPT  b0af35b31588dc4ab06d5cf2986e8e02      MD
# 2  2013-01-01  18:04:49     MPT  3561a60621de06ab1badc8ca55699ef3      US
# 3  2013-01-01  17:42:40     FXP  1864e5e8013d9414150e91d26b6a558b      SE
# 4  2013-01-01  17:48:29     MPT  1ec336348f44207d2e0027dc3a68c118      NO
#
#   Origin Destination  RoundTrip  NbSegments Seg1Departure  ...  Seg6Carrier  \
# 0    TXL         AUH        1.0         2.0           TXL  ...          NaN
# 1    ATH         MIL        0.0         1.0           ATH  ...          NaN
# 2    ICT         SFO        1.0         2.0           ICT  ...          NaN
# 3    RNB         ARN        0.0         1.0           RNB  ...          NaN
# 4    OSL         MAD        1.0         2.0           OSL  ...          NaN
#
# ...

# %%
df_searches.dtypes
# Out:
# Date                         object
# Time                         object
# TxnCode                      object
# OfficeID                     object
# Country                      object
# Origin                       object
# Destination                  object
# RoundTrip                   float64
# NbSegments                  float64
# Seg1Departure                object
# Seg1Arrival                  object
# Seg1Date                     object
# Seg1Carrier                  object
# Seg1BookingCode              object
# Seg2Departure                object
# Seg2Arrival                  object
# Seg2Date                     object
# Seg2Carrier                  object
# Seg2BookingCode              object
# Seg3Departure                object
# Seg3Arrival                  object
# Seg3Date                     object
# Seg3Carrier                  object
# Seg3BookingCode              object
# Seg4Departure                object
# Seg4Arrival                  object
# ...
